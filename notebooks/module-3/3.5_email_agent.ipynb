# %% [markdown]
# # Email Agent
# - Authenticates users
#   - Only then let user(s) into the inbox
#   - Dynamic tools and prompts based on the authentication stage
# - Checks "inbox"
#   - email in tool
# - Sends emails after getting human approval
#   - Human-in-the-loop

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class EmailContext:
    email_address: str = "pytholic@example.com"
    password: str = "password123"

# %%
from langchain.agents import AgentState

class AuthenticatedState(AgentState):
    authenticated: bool

# %%
from langchain.tools import tool, ToolRuntime
from langgraph.types import Command
from langchain.messages import ToolMessage

@tool
def check_inbox() -> str:
    """Check the inbox for recent emails"""
    return """
    Hi pytholic, 
    I'm going to be in town next week and was wondering if we could grab a coffee?
    - best, John (john@example.com)
    """

@tool
def send_email(to: str, subject: str, body: str) -> str:
    """Send an response email"""
    return f"Email sent to {to} with subject {subject} and body {body}"

@tool
def authenticate(email: str, password: str, runtime: ToolRuntime) -> Command:
    """Authenticate the user with the given email and password"""
    if email == runtime.context.email_address and password == runtime.context.password:
        return Command(update={
            "authenticated": True, 
            "messages": [ToolMessage(
                "Successfully authenticated", 
                tool_call_id=runtime.tool_call_id)]
        })
    else:
        return Command(update={
            "authenticated": False,
            "messages": [ToolMessage(
                "Authentication failed", 
                tool_call_id=runtime.tool_call_id)]
        })

# %%
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
from collections.abc import Callable

@wrap_model_call
def dynamic_tool_call(request: ModelRequest, 
handler: Callable[[ModelRequest], ModelResponse]) -> ModelResponse:
    """Allow read inbox and send email tools only if user provides correct email and password"""
    
    authenticated = request.state.get("authenticated")
    
    if authenticated:
        tools = [check_inbox, send_email]
    else:
        tools = [authenticate]

    request = request.override(tools=tools)
    return handler(request)

# %%
from langchain.agents.middleware import dynamic_prompt

authenticated_prompt = "You are a helpful assistant that can check the inbox and send emails."
unauthenticated_prompt = "You are a helpful assistant that can authenticate users."

@dynamic_prompt
def dynamic_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on authentication status"""
    authenticated = request.state.get("authenticated")

    if authenticated:
        return authenticated_prompt
    else:
        return unauthenticated_prompt

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.0,
)

agent = create_agent(
    model,
    tools=[authenticate, check_inbox, send_email],
    checkpointer=InMemorySaver(),
    state_schema=AuthenticatedState,
    context_schema=EmailContext,
    middleware=[
        dynamic_tool_call, 
        dynamic_prompt,
        HumanInTheLoopMiddleware(
            interrupt_on={
                "authenticate": False,
                "check_inbox": False,
                "send_email": True,
            })
        ]
    )

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    # {"messages": [HumanMessage(content="pytholic@example.com password123")]},
    # {"messages": [HumanMessage(content="Please check my inbox")]},
    # {"messages": [HumanMessage(content="Draft a response to John's email and send it")]},
    {"messages": [HumanMessage(content="Subject: Meetup, Body: Accept and draft a body for me")]},
    context=EmailContext(),
    config=config
)

print(response['messages'][-1].content)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'__interrupt__': [Interrupt(value={'action_requests': [{'args': {'body': 'Hi '
#                                                                           'John,\n'
#                                                                           '\n'
#                                                                           'That '
#                                                                           'sounds '
#                                                                           'great! '
#                                                                           "I'd "
#                                                                           'love '
#                                                                           'to '
#                                                                           'grab '
#                                                                           'a '
#                                                                           'coffee '
#                                                                           'next '
#                                                                           'week. '
#                                                                           'Let '
#                                                                           'me '
#                                                                           'know '
#                                                                           'what '
#                                                                           'day '
#                                                                           'and '
#                                                                           'time '
#                                                                           'works '
#                                                                           'best '
#                                                                           'for '
#                                                                           'you.\n'
#                                                                           '\n'
#                                                                           'Best,\n'
#                                                                           'Pytholic',
#                                                                   'subject': 'Meetup',
#                                                                   'to': 'john@example.com'},
#                                                          'description': 'Tool '
#                                                                         'execution '
#                                                                         'requires '
#                                                                         'approval\n'
#                                                                         '\n'
#                                                                         'Tool: '
#                                                                         'send_email\n'
#                                                                         'Args: '
#                                                                         "{'subject': "
#                                                                         "'Meetup', "
#                                                                         "'body': "
#                                                                         '"Hi '
#                                                                         'John,\\n\\nThat '
#                                                                         'sounds '
#                                                                         'great! '
#                                                                         "I'd "
#                                                                         'love '
#                                                                         'to '
#                                                                         'grab '
#                                                                         'a '
#                                                                         'coffee '
#                                                                         'next '
#                                                                         'week. '
#                                                                         'Let '
#                                                                         'me '
#                                                                         'know '
#                                                                         'what '
#                                                                         'day '
#                                                                         'and '
#                                                                         'time '
#                                                                         'works '
#                                                                         'best '
#                                                                         'for '
#                                                                         'you.\\n\\nBest,\\nPytholic", '
#                                                                         "'to': "
#                                                                         "'john@example.com'}",
#                                                          'name': 'send_email'}],
#                                     'review_configs': [{'action_name': 'send_email',
#                                                         'allowed_decisions': ['approve',
#                                                                               'edit',
#                                                                               'reject']}]},
#                              id='3f066cbdc346afff1ee9ab5dd0d3f426')],
#  'authenticated': True,
#  'messages': [HumanMessage(content='draft 1', additional_kwargs={}, response_metadata={}, id='f7c1c817-83d2-4305-aaa6-6f7f576f1d15'),
#               AIMessage(content=[{'type': 'text', 'text': "I can help with that. What would you like to draft? If you're trying to authenticate, please provide your email and password.", 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff97-ca50-7471-ba10-623784ee48ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 64, 'output_tokens': 123, 'total_tokens': 187, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 95}}),
#               HumanMessage(content='pytholic@example.com password123', additional_kwargs={}, response_metadata={}, id='ff27e1e9-aa72-492b-b996-ed384478d2cd'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'authenticate', 'arguments': '{"password": "password123", "email": "pytholic@example.com"}'}, '__gemini_function_call_thought_signatures__': {'c1c3628a-0706-434b-96ad-913a77e711b3': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff98-6825-7df0-aeb9-5b9758d81468-0', tool_calls=[{'name': 'authenticate', 'args': {'password': 'password123', 'email': 'pytholic@example.com'}, 'id': 'c1c3628a-0706-434b-96ad-913a77e711b3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 105, 'output_tokens': 87, 'total_tokens': 192, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 60}}),
#               ToolMessage(content='Successfully authenticated', name='authenticate', id='2ff53072-3198-4edf-bd53-11b2a27a546b', tool_call_id='c1c3628a-0706-434b-96ad-913a77e711b3'),
#               AIMessage(content='You are successfully authenticated. What would you like to draft?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff98-6dee-71e3-8ee3-7345ad6c4463-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 186, 'output_tokens': 12, 'total_tokens': 198, 'input_token_details': {'cache_read': 0}}),
#               HumanMessage(content='draft 1', additional_kwargs={}, response_metadata={}, id='7e33105b-de81-4332-8b25-1a41b83d013b'),
#               AIMessage(content=[{'type': 'text', 'text': 'I can help you draft an email. What is the subject and body of the email, and to whom should it be sent?', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff98-b045-7442-ad9c-fc5a7a8c6e7a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 203, 'output_tokens': 86, 'total_tokens': 289, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 60}}),
#               HumanMessage(content='Please check my inbox', additional_kwargs={}, response_metadata={}, id='e687ffe8-4c27-4e5f-82f4-b799dab1c580'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'check_inbox', 'arguments': '{}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff99-2cfb-7a81-ba6a-d7467dd808cd-0', tool_calls=[{'name': 'check_inbox', 'args': {}, 'id': '0f6f2054-7934-4404-9ceb-76c776199f64', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 235, 'output_tokens': 11, 'total_tokens': 246, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content="\n    Hi pytholic, \n    I'm going to be in town next week and was wondering if we could grab a coffee?\n    - best, John (john@example.com)\n    ", name='check_inbox', id='e92a6dae-99cd-4e82-800d-242f69e79f9b', tool_call_id='0f6f2054-7934-4404-9ceb-76c776199f64'),
#               AIMessage(content='You have one new email from John (john@example.com) with the subject "Hi pytholic," and the body "I\'m going to be in town next week and was wondering if we could grab a coffee? - best, John (john@example.com)".', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff99-3191-73f1-9412-29ce9b660748-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 306, 'output_tokens': 58, 'total_tokens': 364, 'input_token_details': {'cache_read': 0}}),
#               HumanMessage(content="Draft a response to John's email and send it", additional_kwargs={}, response_metadata={}, id='05fbdb1b-de10-4359-9d08-46d698ed2197'),
#               AIMessage(content=[{'type': 'text', 'text': 'I can help you draft a response to John. What would you like the subject and body of the email to be?', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff99-9b5e-78c3-868a-10fd554d0071-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 377, 'output_tokens': 87, 'total_tokens': 464, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 63}}),
#               HumanMessage(content='Subject: Meetup, Body: Draft it for me please!', additional_kwargs={}, response_metadata={}, id='38924c60-1ffe-4b84-9970-49eddf396094'),
#               AIMessage(content=[{'type': 'text', 'text': 'I can draft a response, but I need a little more information. What would you like to say to John in the email body? For example, would you like to accept his offer for coffee, suggest a different time, or decline?', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff9a-aac1-76f2-917d-749ee2c5ef80-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 416, 'output_tokens': 107, 'total_tokens': 523, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 59}}),
#               HumanMessage(content='Subject: Meetup, Body: Accept and draft a body for me', additional_kwargs={}, response_metadata={}, id='d46379d3-2e90-465a-ac23-68160eebe71d'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'send_email', 'arguments': '{"subject": "Meetup", "body": "Hi John,\\n\\nThat sounds great! I\'d love to grab a coffee next week. Let me know what day and time works best for you.\\n\\nBest,\\nPytholic", "to": "john@example.com"}'}, '__gemini_function_call_thought_signatures__': {'de35ed44-96f3-4062-b9bb-1e72c1e75998': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff9a-f70b-7b80-9683-6a6fbfac8f32-0', tool_calls=[{'name': 'send_email', 'args': {'subject': 'Meetup', 'body': "Hi John,\n\nThat sounds great! I'd love to grab a coffee next week. Let me know what day and time works best for you.\n\nBest,\nPytholic", 'to': 'john@example.com'}, 'id': 'de35ed44-96f3-4062-b9bb-1e72c1e75998', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 480, 'output_tokens': 119, 'total_tokens': 599, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 48}})]}

# %%
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# Hi John,
#
# That sounds great! I'd love to grab a coffee next week. Let me know what day and time works best for you.
#
# Best,
# Pytholic

# %%
from langgraph.types import Command

response = agent.invoke(
    Command( 
        resume={"decisions": [{"type": "approve"}]}  # or "reject"
    ), 
    config=config # Same thread ID to resume the paused conversation
)

print(response["messages"][-1].content)
# Out:
# I've sent an email to John with the subject "Meetup" and the body:
#
# "Hi John,
#
# That sounds great! I'd love to grab a coffee next week. Let me know what day and time works best for you.
#
# Best,
# Pytholic"

# %%
pprint(response)
# Out:
# {'authenticated': True,
#  'messages': [HumanMessage(content='draft 1', additional_kwargs={}, response_metadata={}, id='f7c1c817-83d2-4305-aaa6-6f7f576f1d15'),
#               AIMessage(content=[{'type': 'text', 'text': "I can help with that. What would you like to draft? If you're trying to authenticate, please provide your email and password.", 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff97-ca50-7471-ba10-623784ee48ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 64, 'output_tokens': 123, 'total_tokens': 187, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 95}}),
#               HumanMessage(content='pytholic@example.com password123', additional_kwargs={}, response_metadata={}, id='ff27e1e9-aa72-492b-b996-ed384478d2cd'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'authenticate', 'arguments': '{"password": "password123", "email": "pytholic@example.com"}'}, '__gemini_function_call_thought_signatures__': {'c1c3628a-0706-434b-96ad-913a77e711b3': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff98-6825-7df0-aeb9-5b9758d81468-0', tool_calls=[{'name': 'authenticate', 'args': {'password': 'password123', 'email': 'pytholic@example.com'}, 'id': 'c1c3628a-0706-434b-96ad-913a77e711b3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 105, 'output_tokens': 87, 'total_tokens': 192, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 60}}),
#               ToolMessage(content='Successfully authenticated', name='authenticate', id='2ff53072-3198-4edf-bd53-11b2a27a546b', tool_call_id='c1c3628a-0706-434b-96ad-913a77e711b3'),
#               AIMessage(content='You are successfully authenticated. What would you like to draft?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff98-6dee-71e3-8ee3-7345ad6c4463-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 186, 'output_tokens': 12, 'total_tokens': 198, 'input_token_details': {'cache_read': 0}}),
#               HumanMessage(content='draft 1', additional_kwargs={}, response_metadata={}, id='7e33105b-de81-4332-8b25-1a41b83d013b'),
#               AIMessage(content=[{'type': 'text', 'text': 'I can help you draft an email. What is the subject and body of the email, and to whom should it be sent?', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff98-b045-7442-ad9c-fc5a7a8c6e7a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 203, 'output_tokens': 86, 'total_tokens': 289, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 60}}),
#               HumanMessage(content='Please check my inbox', additional_kwargs={}, response_metadata={}, id='e687ffe8-4c27-4e5f-82f4-b799dab1c580'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'check_inbox', 'arguments': '{}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff99-2cfb-7a81-ba6a-d7467dd808cd-0', tool_calls=[{'name': 'check_inbox', 'args': {}, 'id': '0f6f2054-7934-4404-9ceb-76c776199f64', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 235, 'output_tokens': 11, 'total_tokens': 246, 'input_token_details': {'cache_read': 0}}),
#               ToolMessage(content="\n    Hi pytholic, \n    I'm going to be in town next week and was wondering if we could grab a coffee?\n    - best, John (john@example.com)\n    ", name='check_inbox', id='e92a6dae-99cd-4e82-800d-242f69e79f9b', tool_call_id='0f6f2054-7934-4404-9ceb-76c776199f64'),
#               AIMessage(content='You have one new email from John (john@example.com) with the subject "Hi pytholic," and the body "I\'m going to be in town next week and was wondering if we could grab a coffee? - best, John (john@example.com)".', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff99-3191-73f1-9412-29ce9b660748-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 306, 'output_tokens': 58, 'total_tokens': 364, 'input_token_details': {'cache_read': 0}}),
#               HumanMessage(content="Draft a response to John's email and send it", additional_kwargs={}, response_metadata={}, id='05fbdb1b-de10-4359-9d08-46d698ed2197'),
#               AIMessage(content=[{'type': 'text', 'text': 'I can help you draft a response to John. What would you like the subject and body of the email to be?', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff99-9b5e-78c3-868a-10fd554d0071-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 377, 'output_tokens': 87, 'total_tokens': 464, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 63}}),
#               HumanMessage(content='Subject: Meetup, Body: Draft it for me please!', additional_kwargs={}, response_metadata={}, id='38924c60-1ffe-4b84-9970-49eddf396094'),
#               AIMessage(content=[{'type': 'text', 'text': 'I can draft a response, but I need a little more information. What would you like to say to John in the email body? For example, would you like to accept his offer for coffee, suggest a different time, or decline?', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff9a-aac1-76f2-917d-749ee2c5ef80-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 416, 'output_tokens': 107, 'total_tokens': 523, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 59}}),
#               HumanMessage(content='Subject: Meetup, Body: Accept and draft a body for me', additional_kwargs={}, response_metadata={}, id='d46379d3-2e90-465a-ac23-68160eebe71d'),
#               AIMessage(content='', additional_kwargs={'function_call': {'name': 'send_email', 'arguments': '{"subject": "Meetup", "body": "Hi John,\\n\\nThat sounds great! I\'d love to grab a coffee next week. Let me know what day and time works best for you.\\n\\nBest,\\nPytholic", "to": "john@example.com"}'}, '__gemini_function_call_thought_signatures__': {'de35ed44-96f3-4062-b9bb-1e72c1e75998': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff9a-f70b-7b80-9683-6a6fbfac8f32-0', tool_calls=[{'name': 'send_email', 'args': {'subject': 'Meetup', 'body': "Hi John,\n\nThat sounds great! I'd love to grab a coffee next week. Let me know what day and time works best for you.\n\nBest,\nPytholic", 'to': 'john@example.com'}, 'id': 'de35ed44-96f3-4062-b9bb-1e72c1e75998', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 480, 'output_tokens': 119, 'total_tokens': 599, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 48}}),
#               ToolMessage(content="Email sent to john@example.com with subject Meetup and body Hi John,\n\nThat sounds great! I'd love to grab a coffee next week. Let me know what day and time works best for you.\n\nBest,\nPytholic", name='send_email', id='77226c5d-f0d6-42ee-b63b-14f058a02933', tool_call_id='de35ed44-96f3-4062-b9bb-1e72c1e75998'),
#               AIMessage(content='I\'ve sent an email to John with the subject "Meetup" and the body:\n\n"Hi John,\n\nThat sounds great! I\'d love to grab a coffee next week. Let me know what day and time works best for you.\n\nBest,\nPytholic"', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bff9c-37b8-79e1-93b0-1f23d9564e5e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 621, 'output_tokens': 60, 'total_tokens': 681, 'input_token_details': {'cache_read': 0}})]}
