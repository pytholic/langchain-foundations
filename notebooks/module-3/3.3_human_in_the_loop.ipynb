# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool, ToolRuntime

@tool
def read_email(runtime: ToolRuntime) -> str:
    """Read the current email from the inbox. Returns the full email content."""
    # take email from state
    return runtime.state["email"]

@tool
def send_email(to: str, subject: str, body: str) -> str:
    """Send an email reply.
    
    Args:
        to: The recipient's name
        subject: The email subject line
        body: The complete email body including greeting and signature
    """
    # fake email sending
    return f"Email sent successfully to {to}"

# %%
from langchain.agents import create_agent, AgentState
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="llama3.1:8b",
    temperature=0.0,
)


class EmailState(AgentState):
    email: str


email_agent = create_agent(
    model=model,
    tools=[read_email, send_email],
    state_schema=EmailState,
    checkpointer=InMemorySaver(),
    system_prompt="""You are pytholic's email assistant. 

CRITICAL: You MUST use the send_email tool to send responses. Never write email text directly - always call the send_email tool.

Your workflow:
1. Use read_email tool to read the incoming email
2. Analyze the email content and sender's name
3. Use send_email tool with these parameters:
   - to: recipient's name (from the email)
   - subject: appropriate subject line (e.g., "Re: [original topic]")
   - body: complete professional email with greeting, full response, and signature

Email writing guidelines:
- Address all questions or requests
- Be polite and professional
- Sign as "pytholic"
- Include proper greeting and closing

Remember: ALWAYS use the send_email tool. Do not write email content as plain text.""",
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "read_email": False,
                "send_email": True,
            },
            description_prefix="Tool execution requires approval",
        ),
    ],
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = email_agent.invoke(
    {
        "messages": [HumanMessage(content="Read my email and send a response using the send_email tool.")],
        "email": "Hi pytholic, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John."
    },
    config=config
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'__interrupt__': [Interrupt(value={'action_requests': [{'args': {'body': 'Dear '
#                                                                           'John,\n'
#                                                                           '\n'
#                                                                           'Thank '
#                                                                           'you '
#                                                                           'for '
#                                                                           'reaching '
#                                                                           'out '
#                                                                           'about '
#                                                                           'the '
#                                                                           'potential '
#                                                                           'delay '
#                                                                           'in '
#                                                                           'our '
#                                                                           'meeting '
#                                                                           'tomorrow. '
#                                                                           'I '
#                                                                           'understand '
#                                                                           'that '
#                                                                           'unforeseen '
#                                                                           'circumstances '
#                                                                           'can '
#                                                                           'arise, '
#                                                                           'and '
#                                                                           "I'm "
#                                                                           'more '
#                                                                           'than '
#                                                                           'happy '
#                                                                           'to '
#                                                                           'reschedule '
#                                                                           'at '
#                                                                           'your '
#                                                                           'convenience.\n'
#                                                                           '\n'
#                                                                           'Please '
#                                                                           'let '
#                                                                           'me '
#                                                                           'know '
#                                                                           'a '
#                                                                           'few '
#                                                                           'alternative '
#                                                                           'dates '
#                                                                           'and '
#                                                                           'times '
#                                                                           'that '
#                                                                           'work '
#                                                                           'for '
#                                                                           'you, '
#                                                                           'and '
#                                                                           "I'll "
#                                                                           'do '
#                                                                           'my '
#                                                                           'best '
#                                                                           'to '
#                                                                           'accommodate '
#                                                                           'them.\n'
#                                                                           '\n'
#                                                                           'Looking '
#                                                                           'forward '
#                                                                           'to '
#                                                                           'hearing '
#                                                                           'back '
#                                                                           'from '
#                                                                           'you '
#                                                                           'soon.\n'
#                                                                           '\n'
#                                                                           'Best '
#                                                                           'regards,\n'
#                                                                           'pytholic',
#                                                                   'subject': 'Re: '
#                                                                              'Rescheduling '
#                                                                              "Tomorrow's "
#                                                                              'Meeting',
#                                                                   'to': 'John'},
#                                                          'description': 'Tool '
#                                                                         'execution '
#                                                                         'requires '
#                                                                         'approval\n'
#                                                                         '\n'
#                                                                         'Tool: '
#                                                                         'send_email\n'
#                                                                         'Args: '
#                                                                         "{'to': "
#                                                                         "'John', "
#                                                                         "'subject': "
#                                                                         '"Re: '
#                                                                         'Rescheduling '
#                                                                         "Tomorrow's "
#                                                                         'Meeting", '
#                                                                         "'body': "
#                                                                         '"Dear '
#                                                                         'John,\\n\\nThank '
#                                                                         'you '
#                                                                         'for '
#                                                                         'reaching '
#                                                                         'out '
#                                                                         'about '
#                                                                         'the '
#                                                                         'potential '
#                                                                         'delay '
#                                                                         'in '
#                                                                         'our '
#                                                                         'meeting '
#                                                                         'tomorrow. '
#                                                                         'I '
#                                                                         'understand '
#                                                                         'that '
#                                                                         'unforeseen '
#                                                                         'circumstances '
#                                                                         'can '
#                                                                         'arise, '
#                                                                         'and '
#                                                                         "I'm "
#                                                                         'more '
#                                                                         'than '
#                                                                         'happy '
#                                                                         'to '
#                                                                         'reschedule '
#                                                                         'at '
#                                                                         'your '
#                                                                         'convenience.\\n\\nPlease '
#                                                                         'let '
#                                                                         'me '
#                                                                         'know '
#                                                                         'a few '
#                                                                         'alternative '
#                                                                         'dates '
#                                                                         'and '
#                                                                         'times '
#                                                                         'that '
#                                                                         'work '
#                                                                         'for '
#                                                                         'you, '
#                                                                         'and '
#                                                                         "I'll "
#                                                                         'do my '
#                                                                         'best '
#                                                                         'to '
#                                                                         'accommodate '
#                                                                         'them.\\n\\nLooking '
#                                                                         'forward '
#                                                                         'to '
#                                                                         'hearing '
#                                                                         'back '
#                                                                         'from '
#                                                                         'you '
#                                                                         'soon.\\n\\nBest '
#                                                                         'regards,\\npytholic"}',
#                                                          'name': 'send_email'}],
#                                     'review_configs': [{'action_name': 'send_email',
#                                                         'allowed_decisions': ['approve',
#                                                                               'edit',
#                                                                               'reject']}]},
#                              id='fa2b85afa12adb29b0f2b472b9d6baab')],
#  'email': "Hi pytholic, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Read my email and send a response using the send_email tool.', additional_kwargs={}, response_metadata={}, id='82f28b08-b1db-48bc-a30e-5fd72d363e1d'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:10:56.049317Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3099307875, 'load_duration': 140990958, 'prompt_eval_count': 403, 'prompt_eval_duration': 1643290708, 'eval_count': 35, 'eval_duration': 1295731041, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6e-c20d-7063-b661-a713bcaf2c1a-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'a515b886-f4d7-4a89-a1a6-51e7258b675c', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 403, 'output_tokens': 35, 'total_tokens': 438}),
#               ToolMessage(content="Hi pytholic, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='1a50187c-cfb0-49b5-9e87-2ecbe0c7dd57', tool_call_id='a515b886-f4d7-4a89-a1a6-51e7258b675c'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:11:01.384146Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5322443916, 'load_duration': 92955041, 'prompt_eval_count': 288, 'prompt_eval_duration': 363901875, 'eval_count': 122, 'eval_duration': 4806842040, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6e-ce3b-7ff2-9d1e-461032a4e006-0', tool_calls=[{'name': 'send_email', 'args': {'to': 'John', 'subject': "Re: Rescheduling Tomorrow's Meeting", 'body': "Dear John,\n\nThank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I'm more than happy to reschedule at your convenience.\n\nPlease let me know a few alternative dates and times that work for you, and I'll do my best to accommodate them.\n\nLooking forward to hearing back from you soon.\n\nBest regards,\npytholic"}, 'id': 'aec597d0-9e4f-4099-9ddb-9889cef48257', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 288, 'output_tokens': 122, 'total_tokens': 410})]}

# %%
print(response['__interrupt__'])
# Out:
# [Interrupt(value={'action_requests': [{'name': 'send_email', 'args': {'to': 'John', 'subject': "Re: Rescheduling Tomorrow's Meeting", 'body': "Dear John,\n\nThank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I'm more than happy to reschedule at your convenience.\n\nPlease let me know a few alternative dates and times that work for you, and I'll do my best to accommodate them.\n\nLooking forward to hearing back from you soon.\n\nBest regards,\npytholic"}, 'description': 'Tool execution requires approval\n\nTool: send_email\nArgs: {\'to\': \'John\', \'subject\': "Re: Rescheduling Tomorrow\'s Meeting", \'body\': "Dear John,\\n\\nThank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I\'m more than happy to reschedule at your convenience.\\n\\nPlease let me know a few alternative dates and times that work for you, and I\'ll do my best to accommodate them.\\n\\nLooking forward to hearing back from you soon.\\n\\nBest regards,\\npytholic"}'}], 'review_configs': [{'action_name': 'send_email', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='09415cb8ab78f8cf2f4f50239beaa955')]

# %%
# Access just the 'body' argument from the tool call
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# Dear John,
#
# Thank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I'm more than happy to reschedule at your convenience.
#
# Please let me know a few alternative dates and times that work for you, and I'll do my best to accommodate them.
#
# Looking forward to hearing back from you soon.
#
# Best regards,
# pytholic

# %% [markdown]
# ## Approve

# %%
from langgraph.types import Command

command = Command(resume={"decisions": [{"type": "approve"}]})

response = email_agent.invoke(
    input=command,
    config=config # Same thread_id to resume the same conversation
)

pprint(response)
# Out:
# {'email': "Hi pytholic, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Read my email and send a response using the send_email tool.', additional_kwargs={}, response_metadata={}, id='5064815e-f69b-4d8d-9825-0cd8500804da'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:06:32.695368Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3321624833, 'load_duration': 151597333, 'prompt_eval_count': 403, 'prompt_eval_duration': 1866833167, 'eval_count': 35, 'eval_duration': 1285064790, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6a-bc77-7950-9743-6ef5beac9056-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'c2b0185c-f4ef-4e2f-a083-cf050cc361d1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 403, 'output_tokens': 35, 'total_tokens': 438}),
#               ToolMessage(content="Hi pytholic, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='8043d5e4-6e1c-4710-9409-5f3d0a108603', tool_call_id='c2b0185c-f4ef-4e2f-a083-cf050cc361d1'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:06:37.761226Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5053279250, 'load_duration': 101739334, 'prompt_eval_count': 288, 'prompt_eval_duration': 354505917, 'eval_count': 122, 'eval_duration': 4551885494, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6a-c982-7c60-b9e7-253b66d6f274-0', tool_calls=[{'name': 'send_email', 'args': {'to': 'John', 'subject': "Re: Rescheduling Tomorrow's Meeting", 'body': "Dear John,\n\nThank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I'm more than happy to reschedule at your convenience.\n\nPlease let me know a few alternative dates and times that work for you, and I'll do my best to accommodate them.\n\nLooking forward to hearing back from you soon.\n\nBest regards,\npytholic"}, 'id': '890d7756-1044-4a93-a297-5de1945cf695', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 288, 'output_tokens': 122, 'total_tokens': 410}),
#               ToolMessage(content='Email sent successfully to John', name='send_email', id='ef3b8cfa-4836-43d7-9fd1-7b6ff6e1e633', tool_call_id='890d7756-1044-4a93-a297-5de1945cf695'),
#               AIMessage(content='Would you like me to read another email?', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:06:38.835008Z', 'done': True, 'done_reason': 'stop', 'total_duration': 994706125, 'load_duration': 143035958, 'prompt_eval_count': 420, 'prompt_eval_duration': 484278667, 'eval_count': 10, 'eval_duration': 359664584, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6a-dd8e-7cf3-8387-e4289bde4d07-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 420, 'output_tokens': 10, 'total_tokens': 430})]}

# %%
print(response['messages'][-1].content)
# Out:
# Would you like me to read another email?

# %% [markdown]
# ## Reject

# %%
response = email_agent.invoke(
    Command(        
        resume={
            "decisions": [
                {
                    "type": "reject",
                    # An explanation of why the request was rejected
                    "message": "No please sign off - Your merciful leader, pytholic."
                }
            ]
        }
    ), 
    config=config # Same thread ID to resume the paused conversation
    )   

pprint(response)
# Out:
# {'__interrupt__': [Interrupt(value={'action_requests': [{'args': {'body': 'Dear '
#                                                                           'John,\n'
#                                                                           '\n'
#                                                                           'Thank '
#                                                                           'you '
#                                                                           'for '
#                                                                           'reaching '
#                                                                           'out '
#                                                                           'about '
#                                                                           'the '
#                                                                           'potential '
#                                                                           'delay '
#                                                                           'in '
#                                                                           'our '
#                                                                           'meeting '
#                                                                           'tomorrow. '
#                                                                           'I '
#                                                                           'understand '
#                                                                           'that '
#                                                                           'unforeseen '
#                                                                           'circumstances '
#                                                                           'can '
#                                                                           'arise, '
#                                                                           'and '
#                                                                           "I'm "
#                                                                           'more '
#                                                                           'than '
#                                                                           'happy '
#                                                                           'to '
#                                                                           'reschedule '
#                                                                           'at '
#                                                                           'your '
#                                                                           'convenience.\n'
#                                                                           '\n'
#                                                                           'Please '
#                                                                           'let '
#                                                                           'me '
#                                                                           'know '
#                                                                           'a '
#                                                                           'few '
#                                                                           'alternative '
#                                                                           'dates '
#                                                                           'and '
#                                                                           'times '
#                                                                           'that '
#                                                                           'work '
#                                                                           'for '
#                                                                           'you, '
#                                                                           'and '
#                                                                           "I'll "
#                                                                           'do '
#                                                                           'my '
#                                                                           'best '
#                                                                           'to '
#                                                                           'accommodate '
#                                                                           'them.\n'
#                                                                           '\n'
#                                                                           'Looking '
#                                                                           'forward '
#                                                                           'to '
#                                                                           'hearing '
#                                                                           'back '
#                                                                           'from '
#                                                                           'you '
#                                                                           'soon.\n'
#                                                                           '\n'
#                                                                           'Your '
#                                                                           'Merciful '
#                                                                           'Leader,\n'
#                                                                           'pytholic',
#                                                                   'subject': 'Re: '
#                                                                              'Rescheduling '
#                                                                              "Tomorrow's "
#                                                                              'Meeting',
#                                                                   'to': 'John'},
#                                                          'description': 'Tool '
#                                                                         'execution '
#                                                                         'requires '
#                                                                         'approval\n'
#                                                                         '\n'
#                                                                         'Tool: '
#                                                                         'send_email\n'
#                                                                         'Args: '
#                                                                         "{'to': "
#                                                                         "'John', "
#                                                                         "'body': "
#                                                                         '"Dear '
#                                                                         'John,\\n\\nThank '
#                                                                         'you '
#                                                                         'for '
#                                                                         'reaching '
#                                                                         'out '
#                                                                         'about '
#                                                                         'the '
#                                                                         'potential '
#                                                                         'delay '
#                                                                         'in '
#                                                                         'our '
#                                                                         'meeting '
#                                                                         'tomorrow. '
#                                                                         'I '
#                                                                         'understand '
#                                                                         'that '
#                                                                         'unforeseen '
#                                                                         'circumstances '
#                                                                         'can '
#                                                                         'arise, '
#                                                                         'and '
#                                                                         "I'm "
#                                                                         'more '
#                                                                         'than '
#                                                                         'happy '
#                                                                         'to '
#                                                                         'reschedule '
#                                                                         'at '
#                                                                         'your '
#                                                                         'convenience.\\n\\nPlease '
#                                                                         'let '
#                                                                         'me '
#                                                                         'know '
#                                                                         'a few '
#                                                                         'alternative '
#                                                                         'dates '
#                                                                         'and '
#                                                                         'times '
#                                                                         'that '
#                                                                         'work '
#                                                                         'for '
#                                                                         'you, '
#                                                                         'and '
#                                                                         "I'll "
#                                                                         'do my '
#                                                                         'best '
#                                                                         'to '
#                                                                         'accommodate '
#                                                                         'them.\\n\\nLooking '
#                                                                         'forward '
#                                                                         'to '
#                                                                         'hearing '
#                                                                         'back '
#                                                                         'from '
#                                                                         'you '
#                                                                         'soon.\\n\\nYour '
#                                                                         'Merciful '
#                                                                         'Leader,\\npytholic", '
#                                                                         "'subject': "
#                                                                         '"Re: '
#                                                                         'Rescheduling '
#                                                                         "Tomorrow's "
#                                                                         'Meeting"}',
#                                                          'name': 'send_email'}],
#                                     'review_configs': [{'action_name': 'send_email',
#                                                         'allowed_decisions': ['approve',
#                                                                               'edit',
#                                                                               'reject']}]},
#                              id='49e91ac07dad74c9ec6e7eec18e52a5b')],
#  'email': "Hi pytholic, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Read my email and send a response using the send_email tool.', additional_kwargs={}, response_metadata={}, id='b5efd218-51f6-4701-b7a6-54184f994759'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:07:16.53922Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3884058833, 'load_duration': 110969292, 'prompt_eval_count': 403, 'prompt_eval_duration': 2280944250, 'eval_count': 35, 'eval_duration': 1470584791, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6b-658c-7581-8ac3-df5a37a88639-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'ff53c45d-fa45-4918-9b64-d21002821006', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 403, 'output_tokens': 35, 'total_tokens': 438}),
#               ToolMessage(content="Hi pytholic, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='e2f7e249-6584-4eb8-9f69-22f501432622', tool_call_id='ff53c45d-fa45-4918-9b64-d21002821006'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:07:22.119349Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5557462458, 'load_duration': 98571708, 'prompt_eval_count': 288, 'prompt_eval_duration': 359068958, 'eval_count': 122, 'eval_duration': 5030413217, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6b-74cf-7403-96a6-15d5b2267eb7-0', tool_calls=[{'name': 'send_email', 'args': {'to': 'John', 'subject': "Re: Rescheduling Tomorrow's Meeting", 'body': "Dear John,\n\nThank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I'm more than happy to reschedule at your convenience.\n\nPlease let me know a few alternative dates and times that work for you, and I'll do my best to accommodate them.\n\nLooking forward to hearing back from you soon.\n\nBest regards,\npytholic"}, 'id': 'd7f56bcb-7619-4854-b100-edbb42d9451f', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 288, 'output_tokens': 122, 'total_tokens': 410}),
#               ToolMessage(content='No please sign off - Your merciful leader, pytholic.', name='send_email', id='a9efcfda-416b-4f19-b422-1d8793052046', tool_call_id='d7f56bcb-7619-4854-b100-edbb42d9451f', status='error'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:07:27.492714Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5333014167, 'load_duration': 92336375, 'prompt_eval_count': 429, 'prompt_eval_duration': 581046959, 'eval_count': 119, 'eval_duration': 4602701459, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6b-8aae-7b81-a1b8-a3b7bccc0809-0', tool_calls=[{'name': 'send_email', 'args': {'to': 'John', 'body': "Dear John,\n\nThank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I'm more than happy to reschedule at your convenience.\n\nPlease let me know a few alternative dates and times that work for you, and I'll do my best to accommodate them.\n\nLooking forward to hearing back from you soon.\n\nYour Merciful Leader,\npytholic", 'subject': "Re: Rescheduling Tomorrow's Meeting"}, 'id': '903c3a21-29fd-4693-8cb4-0a81db4294e5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 429, 'output_tokens': 119, 'total_tokens': 548})]}

# %%
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# Dear John,
#
# Thank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I'm more than happy to reschedule at your convenience.
#
# Please let me know a few alternative dates and times that work for you, and I'll do my best to accommodate them.
#
# Looking forward to hearing back from you soon.
#
# Your Merciful Leader,
# pytholic

# %% [markdown]
# ## Edit

# %%
response = email_agent.invoke(
    Command(        
        resume={
            "decisions": [
                {
                    "type": "edit",
                    # Edited action with tool name and args
                    "edited_action": {
                        # Tool name to call.
                        # Will usually be the same as the original action.
                        "name": "send_email",
                        # Arguments to pass to the tool.
                        "args": {
                            "subject": "Re: Meeting Rescheduling",
                            "body": "This is the last straw, you're fired!"
                            },
                    }
                }
            ]
        }
    ), 
    config=config # Same thread ID to resume the paused conversation
    )   

pprint(response)
# Out:
# {'__interrupt__': [Interrupt(value={'action_requests': [{'args': {'body': 'Dear '
#                                                                           'John,\n'
#                                                                           '\n'
#                                                                           "I'm "
#                                                                           'afraid '
#                                                                           'I '
#                                                                           'must '
#                                                                           'correct '
#                                                                           'my '
#                                                                           'previous '
#                                                                           'response. '
#                                                                           'As '
#                                                                           'your '
#                                                                           'leader, '
#                                                                           'I '
#                                                                           'expect '
#                                                                           'a '
#                                                                           'certain '
#                                                                           'level '
#                                                                           'of '
#                                                                           'professionalism '
#                                                                           'from '
#                                                                           'all '
#                                                                           'team '
#                                                                           'members.\n'
#                                                                           '\n'
#                                                                           'Your '
#                                                                           'email '
#                                                                           'was '
#                                                                           'unprofessional '
#                                                                           'and '
#                                                                           'unacceptable. '
#                                                                           'I '
#                                                                           'hereby '
#                                                                           'terminate '
#                                                                           'our '
#                                                                           'meeting '
#                                                                           'and '
#                                                                           'any '
#                                                                           'further '
#                                                                           'communication '
#                                                                           'with '
#                                                                           'you.\n'
#                                                                           '\n'
#                                                                           'You '
#                                                                           'are '
#                                                                           'no '
#                                                                           'longer '
#                                                                           'part '
#                                                                           'of '
#                                                                           'this '
#                                                                           'organization.\n'
#                                                                           '\n'
#                                                                           'Sincerely,\n'
#                                                                           'pytholic',
#                                                                   'to': 'John'},
#                                                          'description': 'Tool '
#                                                                         'execution '
#                                                                         'requires '
#                                                                         'approval\n'
#                                                                         '\n'
#                                                                         'Tool: '
#                                                                         'send_email\n'
#                                                                         'Args: '
#                                                                         "{'to': "
#                                                                         "'John', "
#                                                                         "'body': "
#                                                                         '"Dear '
#                                                                         "John,\\n\\nI'm "
#                                                                         'afraid '
#                                                                         'I '
#                                                                         'must '
#                                                                         'correct '
#                                                                         'my '
#                                                                         'previous '
#                                                                         'response. '
#                                                                         'As '
#                                                                         'your '
#                                                                         'leader, '
#                                                                         'I '
#                                                                         'expect '
#                                                                         'a '
#                                                                         'certain '
#                                                                         'level '
#                                                                         'of '
#                                                                         'professionalism '
#                                                                         'from '
#                                                                         'all '
#                                                                         'team '
#                                                                         'members.\\n\\nYour '
#                                                                         'email '
#                                                                         'was '
#                                                                         'unprofessional '
#                                                                         'and '
#                                                                         'unacceptable. '
#                                                                         'I '
#                                                                         'hereby '
#                                                                         'terminate '
#                                                                         'our '
#                                                                         'meeting '
#                                                                         'and '
#                                                                         'any '
#                                                                         'further '
#                                                                         'communication '
#                                                                         'with '
#                                                                         'you.\\n\\nYou '
#                                                                         'are '
#                                                                         'no '
#                                                                         'longer '
#                                                                         'part '
#                                                                         'of '
#                                                                         'this '
#                                                                         'organization.\\n\\nSincerely,\\npytholic"}',
#                                                          'name': 'send_email'}],
#                                     'review_configs': [{'action_name': 'send_email',
#                                                         'allowed_decisions': ['approve',
#                                                                               'edit',
#                                                                               'reject']}]},
#                              id='8f419a684f6a28cd41facf66f4193307')],
#  'email': "Hi pytholic, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Read my email and send a response using the send_email tool.', additional_kwargs={}, response_metadata={}, id='b5efd218-51f6-4701-b7a6-54184f994759'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:07:16.53922Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3884058833, 'load_duration': 110969292, 'prompt_eval_count': 403, 'prompt_eval_duration': 2280944250, 'eval_count': 35, 'eval_duration': 1470584791, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6b-658c-7581-8ac3-df5a37a88639-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'ff53c45d-fa45-4918-9b64-d21002821006', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 403, 'output_tokens': 35, 'total_tokens': 438}),
#               ToolMessage(content="Hi pytholic, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='e2f7e249-6584-4eb8-9f69-22f501432622', tool_call_id='ff53c45d-fa45-4918-9b64-d21002821006'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:07:22.119349Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5557462458, 'load_duration': 98571708, 'prompt_eval_count': 288, 'prompt_eval_duration': 359068958, 'eval_count': 122, 'eval_duration': 5030413217, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6b-74cf-7403-96a6-15d5b2267eb7-0', tool_calls=[{'name': 'send_email', 'args': {'to': 'John', 'subject': "Re: Rescheduling Tomorrow's Meeting", 'body': "Dear John,\n\nThank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I'm more than happy to reschedule at your convenience.\n\nPlease let me know a few alternative dates and times that work for you, and I'll do my best to accommodate them.\n\nLooking forward to hearing back from you soon.\n\nBest regards,\npytholic"}, 'id': 'd7f56bcb-7619-4854-b100-edbb42d9451f', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 288, 'output_tokens': 122, 'total_tokens': 410}),
#               ToolMessage(content='No please sign off - Your merciful leader, pytholic.', name='send_email', id='a9efcfda-416b-4f19-b422-1d8793052046', tool_call_id='d7f56bcb-7619-4854-b100-edbb42d9451f', status='error'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:07:27.492714Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5333014167, 'load_duration': 92336375, 'prompt_eval_count': 429, 'prompt_eval_duration': 581046959, 'eval_count': 119, 'eval_duration': 4602701459, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6b-8aae-7b81-a1b8-a3b7bccc0809-0', tool_calls=[{'type': 'tool_call', 'name': 'send_email', 'args': {'subject': 'Re: Meeting Rescheduling', 'body': "This is the last straw, you're fired!"}, 'id': '903c3a21-29fd-4693-8cb4-0a81db4294e5'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 429, 'output_tokens': 119, 'total_tokens': 548}),
#               ToolMessage(content='Error invoking tool \'send_email\' with kwargs {\'subject\': \'Re: Meeting Rescheduling\', \'body\': "This is the last straw, you\'re fired!"} with error:\n to: Field required\n Please fix the error and try again.', name='send_email', id='9c20ca03-ee80-4164-a06a-4701655d63fd', tool_call_id='903c3a21-29fd-4693-8cb4-0a81db4294e5', status='error'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:07:36.317035Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4295380250, 'load_duration': 135686333, 'prompt_eval_count': 522, 'prompt_eval_duration': 557312875, 'eval_count': 94, 'eval_duration': 3554312622, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6b-b130-7aa3-af03-9f48b81b6d75-0', tool_calls=[{'name': 'send_email', 'args': {'to': 'John', 'body': "Dear John,\n\nI'm afraid I must correct my previous response. As your leader, I expect a certain level of professionalism from all team members.\n\nYour email was unprofessional and unacceptable. I hereby terminate our meeting and any further communication with you.\n\nYou are no longer part of this organization.\n\nSincerely,\npytholic"}, 'id': 'ce59d744-0a39-4b1a-aa61-2006fa43554c', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 522, 'output_tokens': 94, 'total_tokens': 616})]}

# %% [markdown]
# The tool call failed due to missing args.

# %% [markdown]
# ## Edit - Partial Args Helper
#
# **Why do I need all args for edit?**
#
# The three decision types work differently:
# - **`approve`**: No args needed - just approves the model's proposed action
# - **`reject`**: Only needs a `message` - rejects and provides feedback to the model
# - **`edit`**: Requires **ALL** tool parameters - completely replaces the tool call
#
# When using `"type": "edit"`, you must provide **all** required tool arguments because you're replacing the entire tool call.
#
# **Solution: Extract and merge** - To make partial edits easier, extract the original args first and only override what you want to change:

# %%
response['__interrupt__'][0].value['action_requests'][0]
# Out:
# {'name': 'send_email',
#  'args': {'to': 'John',
#   'subject': "Re: Rescheduling Tomorrow's Meeting",
#   'body': "Dear John,\n\nThank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I'm more than happy to reschedule at your convenience.\n\nPlease let me know a few alternative dates and times that work for you, and I'll do my best to accommodate them.\n\nLooking forward to hearing back from you soon.\n\nBest regards,\npytholic"},
#  'description': 'Tool execution requires approval\n\nTool: send_email\nArgs: {\'to\': \'John\', \'subject\': "Re: Rescheduling Tomorrow\'s Meeting", \'body\': "Dear John,\\n\\nThank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I\'m more than happy to reschedule at your convenience.\\n\\nPlease let me know a few alternative dates and times that work for you, and I\'ll do my best to accommodate them.\\n\\nLooking forward to hearing back from you soon.\\n\\nBest regards,\\npytholic"}'}

# %%
# Extract original args from the interrupt
original_args = response['__interrupt__'][0].value['action_requests'][0]['args']
print("Original args:", original_args)

# Create new args by merging - only override what you want to change
edited_args = {
    **original_args,  # Keep all original args
    "body": "The meeting cannot be rescheduled. If you do not show, there will be consequences"  # Override just the body
}

print("\nEdited args:", edited_args)
# Out:
# Original args: {'to': 'John', 'subject': "Re: Rescheduling Tomorrow's Meeting", 'body': "Dear John,\n\nThank you for reaching out about the potential delay in our meeting tomorrow. I understand that unforeseen circumstances can arise, and I'm more than happy to reschedule at your convenience.\n\nPlease let me know a few alternative dates and times that work for you, and I'll do my best to accommodate them.\n\nLooking forward to hearing back from you soon.\n\nBest regards,\npytholic"}
#
# Edited args: {'to': 'John', 'subject': "Re: Rescheduling Tomorrow's Meeting", 'body': 'The meeting cannot be rescheduled. If you do not show, there will be consequences'}

# %%
# Now use the edited_args in your edit decision
response = email_agent.invoke(
    Command(        
        resume={
            "decisions": [
                {
                    "type": "edit",
                    "edited_action": {
                        "name": "send_email",
                        "args": edited_args  # Use the merged args
                    }
                }
            ]
        }
    ), 
    config=config
)

pprint(response)
# Out:
# {'email': "Hi pytholic, I'm going to be late for our meeting tomorrow. Can we "
#           'reschedule? Best, John.',
#  'messages': [HumanMessage(content='Read my email and send a response using the send_email tool.', additional_kwargs={}, response_metadata={}, id='82f28b08-b1db-48bc-a30e-5fd72d363e1d'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:10:56.049317Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3099307875, 'load_duration': 140990958, 'prompt_eval_count': 403, 'prompt_eval_duration': 1643290708, 'eval_count': 35, 'eval_duration': 1295731041, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6e-c20d-7063-b661-a713bcaf2c1a-0', tool_calls=[{'name': 'read_email', 'args': {}, 'id': 'a515b886-f4d7-4a89-a1a6-51e7258b675c', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 403, 'output_tokens': 35, 'total_tokens': 438}),
#               ToolMessage(content="Hi pytholic, I'm going to be late for our meeting tomorrow. Can we reschedule? Best, John.", name='read_email', id='1a50187c-cfb0-49b5-9e87-2ecbe0c7dd57', tool_call_id='a515b886-f4d7-4a89-a1a6-51e7258b675c'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:11:01.384146Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5322443916, 'load_duration': 92955041, 'prompt_eval_count': 288, 'prompt_eval_duration': 363901875, 'eval_count': 122, 'eval_duration': 4806842040, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6e-ce3b-7ff2-9d1e-461032a4e006-0', tool_calls=[{'type': 'tool_call', 'name': 'send_email', 'args': {'to': 'John', 'subject': "Re: Rescheduling Tomorrow's Meeting", 'body': 'The meeting cannot be rescheduled. If you do not show, there will be consequences'}, 'id': 'aec597d0-9e4f-4099-9ddb-9889cef48257'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 288, 'output_tokens': 122, 'total_tokens': 410}),
#               ToolMessage(content='Email sent successfully to John', name='send_email', id='b57d3075-45f0-47d4-8e89-b8d15f15a44c', tool_call_id='aec597d0-9e4f-4099-9ddb-9889cef48257'),
#               AIMessage(content='Would you like me to read another email?', additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2026-01-27T03:11:09.7945Z', 'done': True, 'done_reason': 'stop', 'total_duration': 921377834, 'load_duration': 110869084, 'prompt_eval_count': 349, 'prompt_eval_duration': 469190625, 'eval_count': 10, 'eval_duration': 331491418, 'logprobs': None, 'model_name': 'llama3.1:8b', 'model_provider': 'ollama'}, id='lc_run--019bfd6f-0047-7312-a7c5-2a1178ddc966-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 349, 'output_tokens': 10, 'total_tokens': 359})]}

# %% [markdown]
# Trace: https://smith.langchain.com/public/c50fc684-7a73-4f10-96cb-7ac2fd4ba7a9/r

# %% [markdown]
# Note:
# - I recommend re-running the initial email call before each part (approve ,reject, edit) to have clear context.
